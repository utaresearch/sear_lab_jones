# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df=pd.read_excel("bills_Homestead_Oaks_Aggregate_Tenant_Net_Meter_Elec.xls")

# %%
import matplotlib.pyplot as plt

# %%
df['Start Date'] = pd.to_datetime(df['Start Date'])
df['StartYear'], df['StartMonth'] = df['Start Date'].dt.year, df['Start Date'].dt.month

# %%
df['End Date'] = pd.to_datetime(df['End Date'])
df['EndYear'], df['EndMonth'] = df['End Date'].dt.year, df['End Date'].dt.month

# %%
Groups=df.groupby('StartYear')['StartMonth']

# %%
print(Groups)
# Out:
# <pandas.core.groupby.generic.SeriesGroupBy object at 0x000001DE04AF7460>

# %%
df.head(10)
# Out:
#    Fuel Start Date   End Date  Days Billed  Usage Units  Bill Amount  \
# 0   NaN 2015-11-01 2015-11-30           30   1598   kWh            0
# 1   NaN 2015-12-01 2015-12-31           31  13514   kWh            0
# 2   NaN 2016-01-01 2016-01-31           31  21466   kWh            0
# 3   NaN 2016-02-01 2016-02-29           29  23617   kWh            0
# 4   NaN 2016-03-01 2016-03-31           31  35591   kWh            0
# 5   NaN 2016-04-01 2016-04-30           30  38352   kWh            0
# 6   NaN 2016-05-01 2016-05-31           31  43396   kWh            0
# 7   NaN 2016-06-01 2016-06-30           30  47253   kWh            0
# 8   NaN 2016-07-01 2016-07-31           31  71252   kWh            0
# 9   NaN 2016-08-01 2016-08-31           31  79034   kWh            0
#
#    StartYear  StartMonth  EndYear  EndMonth
# 0       2015          11     2015        11
# 1       2015          12     2015        12
# 2       2016           1     2016         1
# 3       2016           2     2016         2
# 4       2016           3     2016         3
# 5       2016           4     2016         4
# 6       2016           5     2016         5
# 7       2016           6     2016         6
# 8       2016           7     2016         7
# 9       2016           8     2016         8

# %%
x=df['StartYear']
y=df['Usage']
plt.bar(x,y,color='Green',width=0.5)
plt.title('Graph plotted between the usage and months')
plt.xlabel('Years')
plt.ylabel('Usage')
plt.show()

# %%
x=df['StartMonth']
y=df['Usage']
plt.bar(x,y,color='Green',width=0.5)
plt.title('Graph plotted between the usage and months')
plt.show()

# %%
x=df['StartYear']
y=df['Usage']
plt.plot(x,y)
plt.title('Graph plotted between the usage and months')
plt.xlabel('Years')
plt.ylabel('Usage')
plt.show()

# %%
x=df.groupby('StartYear')['Usage'].sum()
labels = '2015', '2016', '2017', '2018','2019','2020','2021'
plt.pie(x,labels=labels)
plt.show()

# %%
x=df['StartYear']
y=df['Usage']

plt.scatter(x,y)
plt.show()

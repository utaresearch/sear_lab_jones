# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("bills_Homestead_Oaks_HO_Irrigation.xls")

# %%
df.head(10)
# Out:
#    Fuel  Start Date    End Date  Days Billed   Usage    Units  Bill Amount
# 0   NaN  09/21/2015  10/09/2015           18       0  Gallons       121.00
# 1   NaN  10/09/2015  11/02/2015           24       0  Gallons       190.00
# 2   NaN  11/02/2015  12/08/2015           36   14800  Gallons       265.33
# 3   NaN  12/08/2015  01/09/2016           32   59400  Gallons       492.35
# 4   NaN  01/09/2016  02/08/2016           30  235500  Gallons      1388.70
# 5   NaN  02/08/2016  03/09/2016           30  291000  Gallons      1671.19
# 6   NaN  03/09/2016  04/08/2016           30  172500  Gallons      1068.03
# 7   NaN  04/08/2016  05/09/2016           31   35200  Gallons       369.17
# 8   NaN  05/09/2016  06/09/2016           31   35200  Gallons       369.17
# 9   NaN  06/09/2016  07/11/2016           32   71800  Gallons       590.64

# %%
df.drop('Fuel',axis=1,inplace=True)

# %%
df.head(10)
# Out:
#    Start Date    End Date  Days Billed   Usage    Units  Bill Amount
# 0  09/21/2015  10/09/2015           18       0  Gallons       121.00
# 1  10/09/2015  11/02/2015           24       0  Gallons       190.00
# 2  11/02/2015  12/08/2015           36   14800  Gallons       265.33
# 3  12/08/2015  01/09/2016           32   59400  Gallons       492.35
# 4  01/09/2016  02/08/2016           30  235500  Gallons      1388.70
# 5  02/08/2016  03/09/2016           30  291000  Gallons      1671.19
# 6  03/09/2016  04/08/2016           30  172500  Gallons      1068.03
# 7  04/08/2016  05/09/2016           31   35200  Gallons       369.17
# 8  05/09/2016  06/09/2016           31   35200  Gallons       369.17
# 9  06/09/2016  07/11/2016           32   71800  Gallons       590.64

# %%
df['Start Date'] = pd.to_datetime(df['Start Date'])
df['StartYear'], df['StartMonth'] = df['Start Date'].dt.year, df['Start Date'].dt.month

# %%
df['End Date'] = pd.to_datetime(df['End Date'])
df['EndYear'], df['EndMonth'] = df['End Date'].dt.year, df['End Date'].dt.month

# %%
x=df['StartYear']
y=df['Usage']
plt.bar(x,y,color='Green',width=0.5)
plt.title('Graph plotted between the usage and months')
plt.xlabel('Years')
plt.ylabel('Usage')
plt.show()

# %%
x=df['StartYear']
y=df['Bill Amount']
plt.bar(x,y,color='Green',width=0.5)
plt.title('Graph plotted between the years and the Total_Bill')
plt.xlabel('Years')
plt.ylabel('Bill Amount')
plt.show()

# %%
x=df.groupby('StartYear')['Usage'].sum()
labels = '2015', '2016', '2017', '2018','2019','2020','2021','2022'
plt.pie(x,labels=labels)
plt.title("Graph Plotted between Usage and Start Year")
plt.show()

# %%
x=df.groupby('StartYear')['Bill Amount'].sum()
labels = '2015', '2016', '2017', '2018','2019','2020','2021','2022'
plt.pie(x,labels=labels)
plt.title("Graph Plotted between Total_Bill and Start Year")
plt.show()

# %%
x=df['StartYear']
y=df['Usage']
plt.title("Plot between Start Year and Usage")
plt.scatter(x,y)
plt.show()

# %%
x=df['StartYear']
y=df['Bill Amount']
plt.title("Plot between Start Year and Bill Amount")
plt.scatter(x,y)
plt.show()

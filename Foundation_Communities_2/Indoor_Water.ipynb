# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("bills_Homestead_Oaks_HO_Indoor_Water.xls")

# %%
df.head(10)
# Out:
#    Fuel  Start Date    End Date  Days Billed   Usage    Units  Bill Amount  \
# 0   NaN  09/21/2015  10/09/2015           18       0  Gallons       382.00
# 1   NaN  10/09/2015  11/06/2015           28    1400  Gallons       611.13
# 2   NaN  11/06/2015  12/08/2015           32   50900  Gallons       865.68
# 3   NaN  12/08/2015  01/09/2016           32   35300  Gallons       799.28
# 4   NaN  01/09/2016  02/08/2016           30   93800  Gallons      1097.04
# 5   NaN  02/08/2016  03/09/2016           30  205000  Gallons      1663.05
# 6   NaN  03/09/2016  04/08/2016           30  254600  Gallons      1915.51
# 7   NaN  04/08/2016  05/09/2016           31  291800  Gallons      2104.86
# 8   NaN  05/09/2016  06/09/2016           31  291800  Gallons      2114.22
# 9   NaN  06/09/2016  07/11/2016           32  383900  Gallons      2771.12
#
#    Sewer Charges
# 0          10.30
# 1          23.18
# 2         478.58
# 3         335.06
# 4         873.26
# 5        1896.30
# 6        2352.62
# 7        2940.32
# 8        2940.32
# 9        3787.64

# %%
df.drop('Fuel',axis=1,inplace=True)

# %%
df['Total_Bill']=df['Bill Amount']+df['Sewer Charges']

# %%
df['Start Date'] = pd.to_datetime(df['Start Date'])
df['StartYear'], df['StartMonth'] = df['Start Date'].dt.year, df['Start Date'].dt.month

# %%
df['End Date'] = pd.to_datetime(df['End Date'])
df['EndYear'], df['EndMonth'] = df['End Date'].dt.year, df['End Date'].dt.month

# %%
df.head(10)
# Out:
#   Start Date    End Date  Days Billed   Usage    Units  Bill Amount  \
# 0 2015-09-21  10/09/2015           18       0  Gallons       382.00
# 1 2015-10-09  11/06/2015           28    1400  Gallons       611.13
# 2 2015-11-06  12/08/2015           32   50900  Gallons       865.68
# 3 2015-12-08  01/09/2016           32   35300  Gallons       799.28
# 4 2016-01-09  02/08/2016           30   93800  Gallons      1097.04
# 5 2016-02-08  03/09/2016           30  205000  Gallons      1663.05
# 6 2016-03-09  04/08/2016           30  254600  Gallons      1915.51
# 7 2016-04-08  05/09/2016           31  291800  Gallons      2104.86
# 8 2016-05-09  06/09/2016           31  291800  Gallons      2114.22
# 9 2016-06-09  07/11/2016           32  383900  Gallons      2771.12
#
#    Sewer Charges  Total_Bill  StartYear  StartMonth
# 0          10.30      392.30       2015           9
# 1          23.18      634.31       2015          10
# 2         478.58     1344.26       2015          11
# 3         335.06     1134.34       2015          12
# 4         873.26     1970.30       2016           1
# 5        1896.30     3559.35       2016           2
# 6        2352.62     4268.13       2016           3
# 7        2940.32     5045.18       2016           4
# 8        2940.32     5054.54       2016           5
# 9        3787.64     6558.76       2016           6

# %%
x=df['StartYear']
y=df['Usage']
plt.bar(x,y,color='Green',width=0.5)
plt.title('Graph plotted between the usage and Years')
plt.xlabel('Years')
plt.ylabel('Usage')
plt.show()

# %%
x=df['StartYear']
y=df['Total_Bill']
plt.bar(x,y,color='Green',width=0.5)
plt.title('Graph plotted between the usage and Total Bill')
plt.xlabel('Years')
plt.ylabel('Total Bill')
plt.show()

# %%
x=df.groupby('StartYear')['Usage'].sum()
labels = '2015', '2016', '2017', '2018','2019','2020','2021','2022'
plt.pie(x,labels=labels)
plt.title("Graph Plotted between Usage and Start Year")
plt.show()

# %%
x=df.groupby('StartYear')['Total_Bill'].sum()
labels = '2015', '2016', '2017', '2018','2019','2020','2021','2022'
plt.pie(x,labels=labels)
plt.title("Graph Plotted between Total_Bill and Start Year")
plt.show()

# %%
x=df['StartYear']
y=df['Usage']
plt.title("Plot between Start Year and Usage")
plt.scatter(x,y)
plt.show()

# %%
x=df['StartYear']
y=df['Total_Bill']
plt.title("Plot between Start Year and Total Bill")
plt.scatter(x,y)
plt.show()
